# %%
# !nvidia-smi
# Out:
# Sun Mar 29 03:56:52 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %pip install segmentation-models-pytorch opencv-python-headless
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 6.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Replace 'data.zip' with the actual path if it's in a folder, e.g., 'Project/data.zip'
# !unzip /content/drive/MyDrive/data.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/data.zip
#    creating: /content/data/processed_mg/
#    creating: /content/data/processed_mg/test/
#    creating: /content/data/processed_mg/test/images/
#   inflating: /content/data/processed_mg/test/images/MG_Standard_0.png
#   inflating: /content/data/processed_mg/test/images/MG_Standard_1.png
#   inflating: /content/data/processed_mg/test/images/MG_Standard_10.png
#   inflating: /content/data/processed_mg/test/images/MG_Standard_11.png
#   inflating: /content/data/processed_mg/test/images/MG_Standard_12.png
#   inflating: /content/data/processed_mg/test/images/MG_Standard_13.png
#   inflating: /content/data/processed_mg/test/images/MG_Standard_14.png
#   inflating: /content/data/processed_mg/test/images/MG_Standard_15.png
#   inflating: /content/data/processed_mg/test/images/MG_Standard_16.png
#   inflating: /content/data/processed_mg/test/images/MG_Standard_17.png
#   inflating: /content/data/processed_mg/test/images/MG_Standard_18.png
# ...

# %%
# !ls /content/data/processed_us/train/images | head -n 5
# Out:
# US_benign_0.png
# US_benign_100.png
# US_benign_101.png
# US_benign_104.png
# US_benign_105.png

# %%
# %run train.py --mode us
# Out:
# 🚀 BOSS Training Initialized: US on Tesla T4
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/156 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/102M [00:00<?, ?B/s]
# Epoch [1/80] - Loss: 0.7224
# Epoch [2/80] - Loss: 0.5391
# Epoch [3/80] - Loss: 0.3989
# Epoch [4/80] - Loss: 0.3244
# Epoch [5/80] - Loss: 0.2603
# Epoch [6/80] - Loss: 0.2282
# Epoch [7/80] - Loss: 0.2140
# Epoch [8/80] - Loss: 0.1854
# Epoch [9/80] - Loss: 0.1429
# Epoch [10/80] - Loss: 0.1582
# ...

# %%
# Run this if you want to copy what's been trained so far to safety
# !cp -r models/ /content/drive/MyDrive/
